# %%
# !pip install python-dotenv langchain openai langsmith
# Out:
# Requirement already satisfied: python-dotenv in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (1.2.2)
# Collecting langchain
#   Using cached langchain-1.2.15-py3-none-any.whl.metadata (5.8 kB)
# Collecting openai
#   Using cached openai-2.32.0-py3-none-any.whl.metadata (31 kB)
# Collecting langsmith
#   Using cached langsmith-0.7.32-py3-none-any.whl.metadata (15 kB)
# Collecting langchain-core<2.0.0,>=1.2.10 (from langchain)
#   Using cached langchain_core-1.2.31-py3-none-any.whl.metadata (4.4 kB)
# Collecting langgraph<1.2.0,>=1.1.5 (from langchain)
#   Using cached langgraph-1.1.6-py3-none-any.whl.metadata (8.0 kB)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain)
#   Using cached pydantic-2.13.1-py3-none-any.whl.metadata (108 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: packaging>=23.2.0 in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.10->langchain) (4.15.0)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core<2.0.0,>=1.2.10->langchain)
#   Using cached uuid_utils-0.14.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from langsmith) (0.28.1)
# Collecting orjson>=3.9.14 (from langsmith)
#   Using cached orjson-3.11.8-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (41 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith)
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: requests>=2.0.0 in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from langsmith) (2.32.5)
# Collecting xxhash>=3.0.0 (from langsmith)
#   Using cached xxhash-3.6.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (13 kB)
# Collecting zstandard>=0.23.0 (from langsmith)
#   Using cached zstandard-0.25.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: anyio in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith) (4.12.1)
# Requirement already satisfied: certifi in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith) (1.0.9)
# Requirement already satisfied: idna in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->langsmith) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain) (3.0.0)
# Collecting langgraph-checkpoint<5.0.0,>=2.1.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached langgraph_checkpoint-4.0.2-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached langgraph_prebuilt-1.0.9-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached langgraph_sdk-0.3.13-py3-none-any.whl.metadata (1.6 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain)
#   Using cached ormsgpack-1.12.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.46.1 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached pydantic_core-2.46.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic<3.0.0,>=2.7.4->langchain)
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting distro<2,>=1.7.0 (from openai)
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai)
#   Using cached jiter-0.14.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting sniffio (from openai)
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>4 in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from openai) (4.67.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/dhru/Downloads/projects/innomatics/venv/lib/python3.13/site-packages (from requests>=2.0.0->langsmith) (2.6.3)
# Using cached langchain-1.2.15-py3-none-any.whl (112 kB)
# Using cached langchain_core-1.2.31-py3-none-any.whl (513 kB)
# Using cached langsmith-0.7.32-py3-none-any.whl (378 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langgraph-1.1.6-py3-none-any.whl (169 kB)
# Using cached langgraph_checkpoint-4.0.2-py3-none-any.whl (51 kB)
# Using cached langgraph_prebuilt-1.0.9-py3-none-any.whl (35 kB)
# Using cached langgraph_sdk-0.3.13-py3-none-any.whl (96 kB)
# Using cached pydantic-2.13.1-py3-none-any.whl (471 kB)
# Using cached pydantic_core-2.46.1-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached uuid_utils-0.14.1-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (345 kB)
# Using cached openai-2.32.0-py3-none-any.whl (1.2 MB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached jiter-0.14.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (353 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached orjson-3.11.8-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (133 kB)
# Using cached ormsgpack-1.12.2-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached xxhash-3.6.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (193 kB)
# Using cached zstandard-0.25.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.5 MB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Installing collected packages: zstandard, xxhash, uuid-utils, typing-inspection, tenacity, sniffio, pydantic-core, ormsgpack, orjson, jsonpatch, jiter, distro, annotated-types, requests-toolbelt, pydantic, openai, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph-prebuilt, langgraph, langchain
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23/23 [langchain]23 [langgraph]checkpoint]
# Successfully installed annotated-types-0.7.0 distro-1.9.0 jiter-0.14.0 jsonpatch-1.33 langchain-1.2.15 langchain-core-1.2.31 langgraph-1.1.6 langgraph-checkpoint-4.0.2 langgraph-prebuilt-1.0.9 langgraph-sdk-0.3.13 langsmith-0.7.32 openai-2.32.0 orjson-3.11.8 ormsgpack-1.12.2 pydantic-2.13.1 pydantic-core-2.46.1 requests-toolbelt-1.0.0 sniffio-1.3.1 tenacity-9.1.4 typing-inspection-0.4.2 uuid-utils-0.14.1 xxhash-3.6.0 zstandard-0.25.0

# %%
from dotenv import load_dotenv
import langchain
import openai

print("All libraries installed ✅")
# Out:
# All libraries installed ✅

# %% [markdown]
# Setup

# %%
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from langchain.prompts import PromptTemplate

load_dotenv()

os.environ["LANGCHAIN_TRACING_V2"] = "true"

print("Setup Done ✅")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 3
#       1 import os
#       2 from dotenv import load_dotenv
# ----> 3 from langchain_openai import ChatOpenAI
#       4 from langchain.prompts import PromptTemplate
#       6 load_dotenv()
#
# ModuleNotFoundError: No module named 'langchain_openai'
